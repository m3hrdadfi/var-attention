# %%
import os
import sys
import textwrap

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.python.client import device_lib
from configuration import config
from utils import data_utils
from ved_var_attn import VarSeq2SeqVarAttnModel
# Out:
# /Users/m3hrdadfi/anaconda3/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
print(device_lib.list_local_devices())
wrapper = textwrap.TextWrapper(width=100)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9173897902608761951
# ]

# %%
current_dir = os.path.abspath('./')
data_dir = current_dir + '/data/'
outputs_dir = current_dir + '/outputs/'
arch_dir = outputs_dir + 'ved-var-attn/'
outputs_data_dir = outputs_dir + 'data/'

logs_dir = arch_dir + 'summary/'
log_str_dir = arch_dir + 'outcome/'
model_checkpoint_dir = arch_dir + 'checkpoints/var-seq2seq-with-atten-'
bleu_path = arch_dir + 'bleu/det-seq2seq-var-attn/'
w2v_dir = outputs_data_dir
w2v_path = w2v_dir + 'w2v_model_news.pkl'


if not os.path.exists(data_dir):
    os.makedirs(data_dir)

if not os.path.exists(outputs_dir):
    os.makedirs(outputs_dir)

if not os.path.exists(arch_dir):
    os.makedirs(arch_dir)

print('Data dir:', data_dir)
print('Outputs dir:', outputs_dir)
print('Arch dir:', arch_dir)

config['data_dir'] = data_dir
config['logs_dir'] = logs_dir
config['log_str_dir'] = log_str_dir
config['model_checkpoint_dir'] = model_checkpoint_dir
config['bleu_path'] = bleu_path
config['wrapper'] = wrapper
config['w2v_dir'] = w2v_dir

input_type = 'content'
output_type = 'title'
decoder_filters = encoder_filters = '!"#$%&()*+/:;<=>@[\\]^`{|}~\t\n'
# Out:
# Data dir: /Users/m3hrdadfi/Projects/hooshvare/ved/data/
# Outputs dir: /Users/m3hrdadfi/Projects/hooshvare/ved/outputs/
# Arch dir: /Users/m3hrdadfi/Projects/hooshvare/ved/outputs/ved-var-attn/

# %%
config
# Out:
# {'experiment': '?',
#  'num_samples': 80000,
#  'preprocessing': True,
#  'lstm_hidden_units': 100,
#  'embedding_size': 300,
#  'num_layers': 1,
#  'encoder_vocab': 40000,
#  'decoder_vocab': 40000,
#  'encoder_num_tokens': 50,
#  'decoder_num_tokens': 30,
#  'dropout_keep_prob': 0.8,
#  'initial_learning_rate': 0.005,
#  'learning_rate_decay': 0.75,
#  'min_learning_rate': 1e-05,
#  'latent_dim': 100,
#  'word_dropout_keep_probability': 0.75,
#  'z_temp': 1.0,
#  'attention_temp': 1.0,
#  'use_hmean': True,
#  'gamma_val': 0.1,
#  'batch_size': 100,
#  'n_epochs': 30,
#  'logs_dir': '/Users/m3hrdadfi/Projects/hooshvare/ved/outputs/ved-var-attn/summary/',
#  'log_str_dir': '/Users/m3hrdadfi/Projects/hooshvare/ved/outputs/ved-var-attn/outcome/',
#  'model_checkpoint_dir': '/Users/m3hrdadfi/Projects/hooshvare/ved/outputs/ved-var-attn/checkpoints/var-seq2seq-with-atten-',
#  'bleu_path': '/Users/m3hrdadfi/Projects/hooshvare/ved/outputs/ved-var-attn/bleu/det-seq2seq-var-attn/',
#  'w2v_dir': '/Users/m3hrdadfi/Projects/hooshvare/ved/outputs/data/',
#  'data_dir': '/Users/m3hrdadfi/Projects/hooshvare/ved/data/',
#  'load_checkpoint': 7,
#  'wrapper': <textwrap.TextWrapper at 0x11bf0f588>}

# %%
print('[INFO] Importing the data')
data_sources = [
    os.path.join(config['data_dir'], 'articles1.csv'),
    os.path.join(config['data_dir'], 'articles2.csv'),
    os.path.join(config['data_dir'], 'articles3.csv'),
]
data = data_utils.create_news_data(
    data_sources,
    num_samples=config['num_samples'],
    preprocessing=config['preprocessing'])
# Out:
# [INFO] Importing the data

# %%
print('[INFO] Tokenizing input and output sequences')
input_sentences = data[input_type].values
output_sentences = data[output_type].values

print('Inputs:', len(input_sentences))
print('Outputs:', len(output_sentences))

x, word2idx_inputs, x_sen = data_utils.tokenize_sequence(
    sentences=input_sentences,
    max_num_words=config['encoder_num_tokens'],
    max_vocab_size=config['encoder_vocab'],
    filters=encoder_filters)

y, word2idx_outputs, y_sen = data_utils.tokenize_sequence(
    sentences=output_sentences,
    max_num_words=config['decoder_num_tokens'],
    max_vocab_size=config['decoder_vocab'],
    filters=decoder_filters)
# Out:
# [INFO] Tokenizing input and output sequences
# Inputs: 79988
# Outputs: 79988

# %%
print('[INFO] Split data into train-valid-test sets')
train_data, valid_data, test_data = data_utils.create_data_split(
    x=[x, x_sen],
    y=[y, y_sen],
    valid_size=.3,
    test_size=.5,
    verbose=True)
(x_train, y_train, x_sen_train, y_sen_train) = train_data
(x_valid, y_valid, x_sen_valid, y_sen_valid) = valid_data
(x_test, y_test, x_sen_test, y_sen_test) = test_data
# Out:
# [INFO] Split data into train-valid-test sets
# [INFO] Training ...
# X Shape: (55991, 50)
# Y Shape: (55991, 30)
#
# [INFO] Validating ...
# X Shape: (11998, 50)
# Y Shape: (11998, 30)
#
# [INFO] Testing ...
# X Shape: (11999, 50)
# Y Shape: (11999, 30)

# %%
print('[INFO] Embeddings vector and matrix')

encoder_embeddings_matrix = data_utils.create_embedding_matrix(
    word_index=word2idx_inputs,
    embedding_dim=config['embedding_size'],
    w2v_path=w2v_path)

decoder_embeddings_matrix = data_utils.create_embedding_matrix(
    word_index=word2idx_outputs,
    embedding_dim=config['embedding_size'],
    w2v_path=w2v_path)

# Re-calculate the vocab size based on the word_idx dictionary
config['encoder_vocab'] = len(word2idx_inputs)
config['decoder_vocab'] = len(word2idx_outputs)
# Out:
# [INFO] Embeddings vector and matrix

# %%
model = VarSeq2SeqVarAttnModel(
    config=config,
    encoder_embeddings_matrix=encoder_embeddings_matrix,
    decoder_embeddings_matrix=decoder_embeddings_matrix,
    encoder_word_index=word2idx_inputs,
    decoder_word_index=word2idx_outputs)
# Out:
# [INFO] Building models ...
# ----> [INFO] Create placeholders for inputs to the model.
# ----> [INFO] Create word embedding for encoder and decoder parts.
# ----> [INFO] Create encoder block.
# ----> [INFO] Create latent space.
# ----> [INFO] Create decoder block.

# %%
if config['load_checkpoint'] != 0:
    checkpoint = config['model_checkpoint_dir'] + str(config['load_checkpoint']) + '.ckpt'
else:
    checkpoint = tf.train.get_checkpoint_state(os.path.dirname('models/checkpoint')).model_checkpoint_path

print('checkpoint:', checkpoint)
# Out:
# checkpoint: /Users/m3hrdadfi/Projects/hooshvare/ved/outputs/ved-var-attn/checkpoints/var-seq2seq-with-atten-7.ckpt

# %%
preds = model.predict(checkpoint, x_test, y_test, y_sen_test)
# Out:
# INFO:tensorflow:Restoring parameters from /Users/m3hrdadfi/Projects/hooshvare/ved/outputs/ved-var-attn/checkpoints/var-seq2seq-with-atten-7.ckpt
# BLEU 1 to 4 : 0.19 | 0.14 | 0.13 | 0.11

# %%
count = 1000
model.show_output_sentences(
    preds[:count],
    y_test[:count],
    x_sen_test[:count],
    y_sen_test[:count],
    '%s/%s' % (config['log_str_dir'], 'output_sentences.csv'))
# Out:
# Input:      Since Donald Trump named Stephen K. Bannon as his White House Senior Counselor and Reince Priebus as
# his Chief of Staff, many media reports have emerged, speculating on several other names inside
# Trump’s inner circle rumored to fill positions in the Trump administration.
# Actual:     Speculation Circulates around President-elect Donald Trump’s Cabinet - Breitbart
# Generated: the photographers of the trump unverified
#
# Input:      MANILA — Since Rodrigo Duterte became president of the Philippines just over a month ago, promising
# to get tough on crime by having the police and the military kill drug suspects, 420 people have been
# killed in the campaign, according to tallies of police reports by the local news media.
# Actual:     Body Count Rises as Philippine President Wages War on Drugs - The New York Times
# Generated: the UNK of the UNK one
#
# Input:      MUNICH — Years after World War II, American officials here entrusted more than 10, 000 confiscated
# artworks to Bavarian authorities to return to the rightful owners, many of them Jews whose property
# had been plundered.
# Actual:     Nazi Art Loot Returned ... to Nazis - The New York Times
# Generated: obama’s UNK rupert UNK to every UNK home after UNK
#
# Input:      LOS ANGELES — SpaceX has launched a Falcon 9 rocket for the first time since on a Florida launch pad
# more than four months ago.
# Actual:     SpaceX launches first rocket since launch pad explosion
# Generated: hate to today UNK of UNK UNK
#
# Input:      President Trump took his message “straight to the people” Thursday in a and at times contentious
# press conference that covered Russian relations, leaks to the media, immigration policy, the final
# fate of ObamaCare and a multitude of other subjects.
# Actual:     Trump goes on marathon rant against the media
# Generated: trump is times a UNK for the UNK
#
# Input:      More than a week after militants seized Marawi, the Philippine military suffered a significant blow
# in its bid to retake the southern city: The country’s defense secretary, Delfin Lorenzana, announced
# Thursday that an errant airstrike killed at least 10 of the military’s own soldiers and injured
# seven others.
# Actual:     Philippines Errantly Kills At Least 10 Of Its Own Troops In Fight For Marawi
# Generated: the UNK of the new york not
#
# Input:      President Trump a few moments ago when asked about a potential staff shakeup: ”I think we have had
# one of the most successful 13 weeks in the history of the presidency.”
# Actual:     it is Going Great
# Generated: trump model up of UNK in UNK
#
# Input:      3:23 p. m. ET: Perez wins DNC chairmanship, names Ellison deputy, Former Obama Labor Secretary Tom
# Perez won the DNC chairmanship on second round.
# Actual:     Perez Elected As Chairman Of Democratic National Committee
# Generated: the new york not
#
# Input:      Hollywood actresses furiously personal train and pilates themselves into shape for a role, but Vin
# Diesel’s new has a different fitness regimen to thank: badminton.
# Actual:     ‘XXX’ star’s secret weapon for doing stunts: badminton
# Generated: UNK UNK islamic of UNK UNK
#
# Input:      ’ ’ ’ NEW YORK (Reuters) Jeffrey Gundlach, the chief executive of DoubleLine Capital, said on Friday
# that many asset classes look frothy and his firm continues to hold gold, a traditional along with
# gold miner stocks.
# Actual:     GUNDLACH: ’Sell everything’
# Generated: iranian wins says us is times a UNK
#
# Input:      This article is part of a feature we also send out via email as Politics Policy Daily, a daily
# roundup of events and ideas in American politics written specially for newsletter subscribers.
# Actual:     The Atlantic Politics & Policy Daily: Roses Are Red, Violets Are Blue—Arizona, What Color Are You?
# Generated: UNK UNK UNK UNK UNK UNK UNK
#
# Input:      MoveOn.
# Actual:     Soros-Backed MoveOn.org Leads Campaign Against Hillary’s Superdegelates - Breitbart
# Generated: the UNK of the make games building of UNK
#
# Input:      ’ Both major oil benchmarks, US West Texas Intermediate and Brent crude, closed the later part of
# Tuesday above $50 a barrel.
# Actual:     Oil just did something it has not done for nearly 11 months
# Generated: the UNK of the facts make games building of the make games building
#
# Input:      The you. S. has $19 trillion in debt, and Donald Trump is upset about it.
# Actual:     Donald Trump’s Messy Ideas For Handling The National Debt, Explained
# Generated: the new york not
#
# Input:      “In the walls of the cubicle there were three orifices.
# Actual:     Putin’s Post-Factual Politics
# Generated: the UNK of the UNK
#
# Input:      (Updating: Adding comment from Florida Department of Education) The Florida testing outrages just
# keep on coming.
# Actual:     Autistic boy shows up for standardized test with his service dog. Here’s what happened next.
# Generated: attack dhs UNK to be UNK as UNK soldier all
#
# Input:      Pressure is growing for the Argentinian owner of El Prensa to sell the paper and the rest of its US
# holdings in the wake of the latest round of staff cuts that rocked the paper.
# Actual:     NewsGuild’s president wants to save El Diario
# Generated: the UNK of the UNK of the UNK
#
# Input:      Dhaka, Bangladesh (CNN) A crowd was dining when terrorists invaded the trendy restaurant in a
# diplomatic enclave of Dhaka, the capital of Bangladesh.
# Actual:     Terror attack in Bangladesh: The victims
# Generated: the leader of the UNK
#
# Input:      Teen Vogue is cutting back to four issues a year from 10.
# Actual:     Teen Vogue cuts circulation, focuses on digital
# Generated: looks awards ghostbusters to be a UNK to the UNK
#
# Input:      (CNN) On a historic night, Hillary Clinton proved that a woman nominee for president can deliver
# just as good an acceptance speech as a man and some would say, even better.
# Actual:     Clinton’s questionable decision
# Generated: the leader street stop clinton’s have
#
# Input:      Washington (CNN) FBI Director James Comey discussed Russia with members of the Senate Intelligence
# Committee Friday afternoon, as questions swirl about how expansive lawmakers will make their
# investigations into Russia’s influence in last year’s election.
# Actual:     Comey talks Russia with senators in closed-door briefing
# Generated: the new york not
#
# Input:      THE MORNING PLUM: Bernie Sanders routed Hillary Clinton in Wisconsin last night by unleashing a
# blizzard of headlines about how he has “momentum.
# Actual:     Clinton just blasted Sanders for not being a Democrat. Here’s why.
# Generated: the UNK of the make disaster building of the make disaster democratic
#
# Input:      A Syrian cameraman and rescue worker whose documentary about the civil defence group known as the
# White Helmets has been nominated for an Oscar will not attend the awards ceremony because Damascus
# has cancelled his passport, the group said on Sunday.
# Actual:     White Helmet to miss Oscars because Syria cancelled passport
# Generated: the UNK of the UNK
#
# Input:      While Broadway saw its first $100 annual box office gross in 2014 with “The Lion King,” according to
# Broadway World, “Hamilton” may be poised to eclipse the Disney production.
# Actual:     ‘Hamilton’ could score over $100M in first year on Broadway
# Generated: obama’s - the new york not
#
# Input:      ’ ’ ” Senate Democrats pledged on Monday to reintroduce a bill banning people on the terror watch
# list from buying weapons in the aftermath of Sunday morning’s massacre at an LGBTQ nightclub in
# Orlando, Florida.
# Actual:     ’It makes even more sense today’: Senate Democrats are reviving a controversial bill after the
# Orlando massacre
# Generated: does how to she you.s. it down down
#
# Input:      (CNN) Like the eponymous albino leviathan of Melville’s novel, white has an otherness to it.
# Actual:     The dark truth behind white
# Generated: UNK UNK UNK UNK UNK
#
# Input:      One of the most puzzling injustices in American history is our tradition of eating turkey, a bird
# that excels in its mediocrity, on the best holiday this great nation has to offer.
# Actual:     Meats, ranked
# Generated: the UNK of the UNK
#
# Input:      AP AP AP AP AP AP AP View Slideshow DUBAI, United Arab Emirates — Surrounded by 300 deserted
# islands, Dubai’s newest wonder has all the amenities of a luxury hotel — plus views of the bottom of
# the sea.
# Actual:     These ridiculous floating homes are peak Dubai
# Generated: the UNK of the UNK
#
# Input:      One week from today, the Senate Committee on Health, Education, Labor, and Pensions will hold its
# confirmation hearing for Betsy DeVos, Donald Trump’s pick for you. S. secretary of education.
# Actual:     What Betsy DeVos Should Tell the Senate
# Generated: the million for the new york not
#
# Input:      President Trump stood by his campaign promise to build a wall along the southern border Thursday,
# telling reporters: “Walls work — just ask Israel.
# Actual:     Trump Tells Reporters: ‘Walls Work - Just Ask Israel’ - Breitbart
# Generated: trump hln 2016 on UNK chief
#
# Input:      In the sunlit courtyard of a mosque, overlooked by jagged mountains, dozens of men arrive to offer
# condolences to the family of Brigadier Hamid Birmous.
# Actual:     Iraqi Forces Shaken By ISIS Resistance In Fight For Mosul
# Generated: the UNK of the UNK
#
# Input:      Washington (CNN) President Donald Trump pledged during the campaign that he would divorce himself
# from the operations of his businesses.
# Actual:     At properties that bear his name, the President is a regular
# Generated: trump is times a UNK
#
# Input:      Sunday on ABC’s “This Week,” while discussing the possibility of Donald Trump picking former Gov.
# Actual:     Conway: Romney ’Went Out of His Way to Hurt Donald Trump’ - Breitbart
# Generated: got the UNK street stop clinton’s UNK
#
# Input:      aread the relevant court documents, made available by BuzzFeed News:’] WASHINGTON — If no court
# steps in, Arkansas is poised to become the first state in more than 15 years to execute two people
# in one night — just four days after the state held its first execution in more
# Actual:     Arkansas Is Fighting To Carry Out Executions Before Drugs Expire
# Generated: the UNK of the UNK court
#
# Input:      ’ ’ ’ Donald Trump and Russian President Vladimir Putin went back and forth making public statement
# about this week, days after President Barack Obama to warn Russia against continued hacking.
# Actual:     US relations with Russia hit rough patch, but there are signs things may soon improve
# Generated: trump has vindictive 9 politico’s
#
# Input:      I want to receive updates from partners and sponsors.
# Actual:     Veep Goes Tragi-Karmic
# Generated: the UNK of the UNK
#
# Input:      For a decade, he told a generation to “stay thirsty, my friends.
# Actual:     Firing the ‘most interesting man’ means disaster for Dos Equis
# Generated: the UNK of the UNK
#
# Input:      Jack Dorsey — and he got an earful.
# Actual:     Jack Dorsey turns to Twitter users for answers
# Generated: the UNK of the UNK
#
# Input:      ’Chromebooks are so close.’ ”Apple’s Mac lineup appears set for the foreseeable future, but with
# there is no one notebook that costs less than $1, 299.” ’The momentum behind super affordable
# Windows laptops, meanwhile, has faded — and what is available for less than $400 is typically marked
# by flimsy
# Actual:     If you can wait, you should not buy a Google Chromebook right now
# Generated: left is times a UNK UNK
#
# Input:      Hello!
# Actual:     it is that special time of the month: Vagina Dispatches episode two
# Generated: the UNK of the UNK
#
# Input:      If you are lucky enough to catch a lift with San Francisco — based Uber driver Stroy Moyd, you will
# get more than a ride across town.
# Actual:     This Uber driver has been turning his rides into a dating game show
# Generated: the UNK of the UNK
#
# Input:      ’ ’ ’ Foreign students studying at US universities are seen to cheat more than American students,
# according to a analysis.
# Actual:     The flood of foreign students at US universities is having an unintended consequence
# Generated: the new york not
#
# Input:      Hollywood has had its fill of Hillary Clinton’s endless dissection of what went wrong with the
# election.
# Actual:     Hillary needs to move on from her loss already
# Generated: the UNK of the UNK
#
# Input:      Milwaukee County Sheriff David Clarke clashed with CNN host Don Lemon over the “hateful ideology” of
# the Black Lives Matter movement, emphasizing that crime is a far more serious threat to black males
# than cops.
# Actual:     Sheriff David Clarke Clashes With Don Lemon in Cleveland Over ’Hateful Ideology’ of Black Lives
# Matter - Breitbart
# Generated: the UNK of the make games ‘we of the make disaster consumer ‘we
#
# Input:      HOUSTON, Texas — Republican presidential candidate Ted Cruz was greeted by Texas Governor Greg
# Abbott and hundreds of enthusiastic supporters today at a rally in Houston.
# Actual:     Texas Governor Gives Enthusiastic Endorsement to Supporters at Cruz Rally in Houston
# Generated: the UNK of the UNK
#
# Input:      One of the country’s largest chains of colleges has been handed a virtual death sentence by the
# Education Department, with its stock losing more than a third of its value in the hours following
# the announcement.
# Actual:     Government Delivers Killer Blow Against For-Profit College Chain ITT
# Generated: the UNK of the UNK
#
# Input:      With the Rangers facing playoff extinction in Tuesday night’s Game 6 against the Senators at the
# Garden, they do not have even a single Stanley Cup winner in the lineup or on the roster.
# Actual:     there is something unfamiliar about this Rangers team
# Generated: the UNK of the UNK
#
# Input:      Veteran Associated Press IAEA reporter George Jahn made news yesterday by revealing a secret
# agreement to the July 2015 nuclear deal with Iran (the Joint Comprehensive Plan of Action, or
# JCPOA).
# Actual:     Obama Withheld from Congress Another Secret Side Deal with the Iranians
# Generated: UNK UNK UNK UNK UNK UNK UNK
#
# Input:      With three small words, Draymond Green confirmed what we have all been wondering about the Golden
# State Warriors and the Cleveland Cavaliers.
# Actual:     Warriors show they hold the edge over Cleveland in the NBA’s fiercest rivalry
# Generated: the new york during
#
# Input:      Over the course of his presidential campaign, I came to admire and respect former GOP presidential
# candidate Dr. Ben Carson.
# Actual:     Dr. Manny: What Carson’s Trump endorsement means for health care
# Generated: the two of the UNK
#
# Input:      When Andrew Brandeis encounters patients who are skeptical about vaccines at his clinic in San
# Francisco, he does not toe the typical pediatrician party line — that the standard vaccine schedule
# is a .
# Actual:     The Shadow Network of Anti-Vax Doctors
# Generated: the new seal seal
#
# Input:      Georgia Governor Nathan Deal said on Monday he will veto a religious freedom bill passed by the
# state legislature that has drawn national criticism for discriminating against couples.
# Actual:     Georgia governor to veto religious protection seen as anti-gay
# Generated: the UNK of the UNK
#
# Input:      House Speaker Paul Ryan, who said on Thursday he was not ready to back Donald Trump for president,
# invited the presumptive Republican nominee to meet with House Republican leaders next week.
# Actual:     Paul Ryan invites Trump to meet with Republican leaders
# Generated: the photographers of the trump releases
#
# Input:      House Speaker Paul Ryan urges conservatives to rally around his leadership in 2016, to focus on
# economic growth and to avoid emotional “hot button issues” and “identity politics.
# Actual:     Speaker Ryan Pushes Conservatives To Back His ’Jack Kemp’ Pro-Immigration Economic Agenda -
# Breitbart
# Generated: the UNK of the make games controversy
#
# Input:      RAMADI, Iraq — The Islamic State is nearing defeat on the battlefield, but away from the front lines
# its members are seeping back into areas the group once controlled, taking advantage of rampant
# corruption in Iraq’s security forces and institutions.
# Actual:     Away from Iraq’s front lines, the Islamic State is creeping back in
# Generated: the new york not
#
# Input:      does not anybody here know how to work this thing?
# Actual:     Trump opponents find an ally: Republican incompetence
# Generated: the 2017 of the UNK growth
#
# Input:      Republican presidential nominee Donald Trump’s you. S. military buildup plan would cost hundreds of
# billions of dollars but with no apparent strategy, defense experts from across the political
# spectrum said on Thursday.
# Actual:     Trump would spend billions more on military, but for what? experts ask
# Generated: the leader of the UNK
#
# Input:      who on Friday confessed to killing him, sources said.
# Actual:     Masseur admits he killed ex-gay club owner during rubdown
# Generated: the UNK of the UNK
#
# Input:      Steve Bannon, the media executive and White House strategist, has been describing Donald Trump’s
# victory as just the beginning.
# Actual:     Donald Trump and the Legacy of Andrew Jackson
# Generated: the UNK of the UNK
#
# Input:      There is a photograph that is been seen around the world this week.
# Actual:     Living Among the Ruins In Aleppo, A Man Keeps Playing His Songs
# Generated: makes paul stocks UNK to experience meeting gop trump
#
# Input:      Since Trump’s stunning Election Day victory last week, social media hashtags like #AssassinateTrump
# and #Killtrump have proliferated.
# Actual:     Anti-Trump message takes darker turn with calls for assassination
# Generated: the stitched of the because is heroes the new york not
#
# Input:      Why is PayPal and venture capitalist Peter Thiel backing Donald Trump for president?
# Actual:     Peter Thiel and the Trump Bubble
# Generated: yet are times a UNK
#
# Input:      Hillary Clinton is scheduled to give a speech Monday afternoon at the University of criticizing
# Senate Republicans for their refusal to consider President Obama’s Supreme Court nominee, Merrick
# Garland.
# Actual:     WATCH LIVE: Clinton To Bash GOP SCOTUS Blockade At 4:45 PM ET
# Generated: the speechwriter UNK
#
# Input:      Listeners of Breitbart News Daily and Breitbart News Sunday on SiriusXM called into the shows to
# discuss their reaction to seeing the film Clinton Cash during its global premiere on Breitbart over
# the weekend.
# Actual:     America Reacts to ‘Clinton Cash’: ’Will Never Be Voting for Hillary’
# Generated: the american is a UNK news
#
# Input:      While some congressional Republicans signaled they supported President Trump’s Tuesday decision to
# fire FBI Director James Comey, at least a few have expressed discomfort with the decision, which
# took Capitol Hill off guard.
# Actual:     Congressional GOPers Question Trump’s Firing Of James Comey
# Generated: the UNK of the UNK
#
# Input:      In Detroit, 12 public school principals are accused of taking kickbacks on supplies that were never
# delivered.
# Actual:     (The Latest) Corruption Charges In Detroit is Struggling Schools
# Generated: the african african of gymnastics african warns
#
# Input:      Today, Ghazala Khan published a Washington Post entitled, ”Trump criticized my silence.
# Actual:     Donald Trump’s fight with the Khans is a reminder of his greatest weakness
# Generated: island UNK UNK UNK UNK
#
# Input:      it is hard to remember a time when the tense 2016 presidential campaign did not hog the airwaves and
# social media feeds.
# Actual:     The Uninvited Guest: The 2016 Campaign Crashes the Dinner Party - The New York Times
# Generated: the UNK of the UNK
#
# Input:      SCOTUS hears oral arguments in United States v. Texas; what is up with the Yahoo sale; a
# disturbingly familiar terrorist attack.
# Actual:     Vox Sentences: Supreme Court Kremlinology, immigration edition
# Generated: the new york not
#
# Input:      I want to receive updates from partners and sponsors.
# Actual:     Elon Musk Is Sorry Foreign Workers May Have Built His Factory For $5 an Hour
# Generated: the UNK of the UNK
#
# Input:      Around 2:30 a. m. last Thursday, a father in Tempe, Ariz. awoke to the sounds of his daughter
# crying, so he left his bedroom to check on her.
# Actual:     A dad was awakened by his toddler’s crying. He found a stranger holding her in the living room.
# Generated: the UNK of the UNK of the UNK
#
# Input:      I want to receive updates from partners and sponsors.
# Actual:     Challenging Culture’s Whiteness by Default
# Generated: the UNK of the UNK
#
# Input:      For us to continue writing great stories, we need to display ads.
# Actual:     A Family Affair at the Democratic National Convention
# Generated: the UNK of the UNK
#
# Input:      Seeing a great work of art might quicken your pulse, but now New York City’s Metropolitan Museum of
# Art is hoping you will break a sweat, too.
# Actual:     Raise Your (He)art Rate With A Workout At The Met
# Generated: the magazine with the make eligibility pay of protect
#
# Input:      The you. S. Supreme Court says it will a case that asks whether immigrants detained by the
# government have a right to a bond hearing to challenge their indefinite detention.
# Actual:     Supreme Court Will Re-Hear Immigrant Indefinite Detention Case
# Generated: UNK UNK to be UNK for UNK
#
# Input:      The turmoil on Wall Street showed no signs of letting up today, as fears about the slowing global
# economy once again sent oil and stock prices tumbling.
# Actual:     Wall Street Has Another Brutal Day, As Stock Prices Plummet
# Generated: the UNK of the UNK of the UNK
#
# Input:      Stories about black women whose employers asked them to cut their dreadlocks or to trim their big
# afros have surfaced with more frequency in the last few years.
# Actual:     New Evidence Shows there is Still Bias Against Black Natural Hair
# Generated: the UNK of the UNK of the UNK
#
# Input:      Despite criticism of presumptive Republican nominee Donald Trump’s support with minorities, a
# Breitbart News analysis suggests Trump actually has more support from Hispanics and African
# Americans than both the two previous Republican nominees had in 2008 and 2012.
# Actual:     Donald Trump Leads Romney, McCain with Minority Voters - Breitbart
# Generated: sex merkel blast year to be extraordinary to trump
#
# Input:      Clairvoyant abilities have a way of thinning the herd when it comes to dating.
# Actual:     ‘Hollywood Medium’ says his abilities give him a dating advantage
# Generated: the UNK of the debut UNK
#
# Input:      CHANHASSEN, Minn. — Prince Rogers Nelson had an unflinching reputation among those close to him for
# leading an assiduously clean lifestyle.
# Actual:     Prince’s Addiction and an Intervention Too Late - The New York Times
# Generated: the UNK of the american
#
# Input:      Update at 3:15 p. m. ET: Ali’s Funeral Set For Friday, Muhammad Ali, the man considered the greatest
# boxer of all time, died late Friday at a hospital in Phoenix at age 74.
# Actual:     Boxer Muhammad Ali, ’The Greatest Of All Time,’ Dies At 74
# Generated: the new york not
#
# Input:      The government of the Central African Republic and 13 of the 14 armed groups in the country on
# Monday signed an accord aimed at ending an ethic and religious conflict that has killed thousands of
# people.
# Actual:     Central African Republic foes sign Church-mediated peace accord
# Generated: the UNK of the UNK
#
# Input:      A gunman deemed mentally unfit to stand trial for killing three people at a Planned Parenthood
# clinic in Colorado last year said in a courtroom outburst on Tuesday that he is being ”forcibly”
# drugged at a state hospital.
# Actual:     Colorado clinic gunman says being drugged against his will
# Generated: UNK UNK to industry serious row in released
#
# Input:      (CNN) Tim Kaine refers to April 16, 2007, as the worst day of his life.
# Actual:     Clinton’s new VP pick could be point man on guns
# Generated: the UNK of the djokovic
#
# Input:      Singer John Legend ripped President Donald Trump in a feature for Fault magazine’s latest issue.
# Actual:     John Legend: Hopefully Trump will not Last the ’Next Four Years’
# Generated: trump is times a UNK
#
# Input:      As soon as one Texas university’s acclaimed dance team announced their Inauguration Day parade
# performance for Donald Trump on January 20, social justice warriors pounced all over the troupe for
# accepting the invitation.
# Actual:     SJW’s Crybully College Dance Troupe for Inauguration Show
# Generated: the new york not
#
# Input:      The Washington Post asked the two major presidential candidates — Democrat Hillary Clinton and
# Republican Donald Trump — to respond to an identical series of questions about their vision and
# plans for public schools should they become president of the United States.
# Actual:     The Washington Post asked Clinton, Trump for their education vision. Here’s what they said.
# Generated: the UNK of the make games building of it
#
# Input:      “Never Forget” has been forgotten.
# Actual:     9/11 monuments across America are defaced and neglected
# Generated: the UNK of the UNK
#
# Input:      European Commission President Juncker has admitted the European Union has tried to take too much
# power from national governments, contributing to the rise in populist movements.
# Actual:     DAMAGE CONTROL: EU Admits Overreach as Populist Victories Loom in 2017
# Generated: confirmed awards ’good UNK is times a UNK for the door of the door
#
# Input:      The complaints obtained by FoxNews.
# Actual:     Man shot by Milwaukee cop beat gun rap after allegedly pressuring witness
# Generated: the designer soldier’s between
#
# Input:      It is unmistakably Christmas on Friday at the Ankawa camp, home to thousands of Iraqi Christians who
# have been displaced since the Islamic State group seized their towns and villages in the Nineveh
# plains of northern Iraq in 2014.
# Actual:     For Iraq’s Christians, Christmas cheer tinged with despair
# Generated: the new york not
#
# Input:      The Republican National Committee announced Monday that Michael Cohen, longtime attorney and ally to
# President Donald Trump, will join its financial team.
# Actual:     Trump Lawyer Michael Cohen Joins RNC’s Finance Team
# Generated: it it change is times a attacks islamists for the trump tell
#
# Input:      No one can accuse Kellyanne Conway of complacency.
# Actual:     do not Blame Never Trump
# Generated: more best times like a ai of UNK
#
# Input:      State and local police have launched an search for a disabled man they say stepped outside his
# parents’ New York home to throw out the trash and was never seen again.
# Actual:     Police search by air, land for missing New York man
# Generated: one of refuse one across nominee to rocket UNK
#
# Input:      It was a slow and gentle plunge: The world’s largest aircraft, the Airlander 10, crashed in southern
# England on Wednesday during its second test flight.
# Actual:     World’s Largest Aircraft Crashes, Gently, in 2nd Test Flight - The New York Times
# Generated: the UNK of the UNK
#
# Input:      Along a snowy highway in the Rockies lies Buford, Wyo.
# Actual:     Buford: Come for the Coffee, Stay ... To Keep The Tiny Town Open
# Generated: the million for the UNK one
#
# Input:      The major indexes each ended up at least 1 percent.
# Actual:     Indexes gain at least 1 percent as financial shares lead
# Generated: the UNK of the facts serious explicit
#
# Input:      The number of men getting vasectomies spiked during the Great Recession, rising from 2006 to 2010, a
# study finds.
# Actual:     When The Economy Goes Down, Vasectomies Go Up
# Generated: the UNK of the UNK
#
# Input:      Another day, another public megaproject from Gov.
# Actual:     The perils of Cuomo’s rush to build, build, build
# Generated: years prison ’a is times a UNK
#
# Input:      Donald Trump’s recent comments that Sen. Ted Cruz may not be constitutionally eligible to be
# President of the United States has sparked discussion on the Constitution’s Natural Born Clause.
# Actual:     Ted Cruz and the Constitution’s ’Natural Born Citizen’ Clause
# Generated: the UNK of the UNK
#
# Input:      THE NEWS this week emerged in such fits and starts, and with such shifting explanations, that its
# grave implications may not have sunk in for many Americans.
# Actual:     What we know Trump did this week — and why it matters
# Generated: the UNK of the UNK
#
# Input:      Sunday on NBC’s “Meet The Press,” former you. S. Senator from Virginia, and 2016 Democratic
# presidential candidate Jim Webb said there was “a campaign” underway on Capitol Hill, in the media
# and academia “to personally discredit” President Donald Trump.
# Actual:     Jim Webb: there is a ‘Campaign’ on the Hill, in Media, Academia to ‘Personally Discredit’ Trump -
# Breitbart
# Generated: the new york not
#
# Input:      Last week, the Sanders campaign announced that it was laying off almost half its staff.
# Actual:     Sanders: we will Try to Win With Super Delegates
# Generated: the stitched of the stitched
#
# Input:      UPDATE 11:35 A. M. The deed is done.
# Actual:     Johnny Manziel is cut by the Browns
# Generated: the UNK of the UNK
#
# Input:      Before NASA put a spacecraft inside the orbit of Ceres, the dwarf planet looked to astronomers like
# a pixelated gray button with mysterious bright spots.
# Actual:     The Icy Secrets of Ceres
# Generated: new york twist
#
# Input:      A handful of former contestants from Donald Trump’s reality show “The Apprentice” say the Republican
# should not be president.
# Actual:     Ex-’Apprentice’ contestants to Donald Trump: We hope you are fired!
# Generated: the UNK of the UNK
#
# Input:      The you. S. Department of Housing and Urban Development (HUD) filed charges on Friday against Bank
# of America ( ) and two of its employees, saying they wrongfully discriminated against prospective
# Hispanic mortgage borrowers in South Carolina.
# Actual:     you.S. housing regulators accuse Bank of America of discriminatory lending
# Generated: the UNK of the UNK
#
# Input:      Paul Manafort quit as Donald Trump’s campaign manager last summer amid questions about his
# consulting work for a disgraced Ukrainian leader who now is a wanted man in his own country.
# Actual:     Paul Manafort’s Activities Arouse Interest Of Ukrainian Prosecutors
# Generated: the leader of the UNK of the UNK
#
# Input:      Health care providers and insurers agree that it is in everyone’s best interest to refer women for
# genetic testing if their family history of breast or ovarian cancer puts them at higher risk.
# Actual:     Want A BRCA Test? Some Insurers Require Genetic Counseling First
# Generated: the UNK of the UNK
#
# Input:      The principal of a Brooklyn elementary school excluded students from a Valentine’s Day party because
# they did not wear pajamas, teachers and parents told The Post.
# Actual:     ‘No pajamas, no party’: Heartless principal bans kids from fun
# Generated: the UNK of the UNK of the UNK
#
# Input:      The State of Texas confirmed its first fatality in Harris County, shortly after an infant was born
# whose mother recently traveled to Latin America.
# Actual:     BREAKING: Texas Confirms Its First Zika Fatality
# Generated: the new york not
#
# Input:      ’ ’ ” Hillary Clinton’s campaign fired back at Donald Trump’s suggestion that Clinton did not have a
# ” ’ “This is not the first time Donald Trump has had a problem looking at someone different from
# himself and actually seeing them,” Hillary for America Deputy Communications Director Christina
# Reynolds
# Actual:     Hillary Clinton’s campaign fires back at Trump’s ’presidential look’ jab
# Generated: the new york not
#
# Input:      Donald Trump won a standing ovation from hundreds of Christian conservatives who came to New York
# City on Tuesday with a somewhat skeptical but willing attitude toward a man who has divided their
# group with comments on women, immigrants and Islam.
# Actual:     Thrilling Christian conservative audience, Trump vows to lift ban on politicking, appoint
# antiabortion judges
# Generated: trump is times a UNK for the UNK
#
# Input:      Good morning.
# Actual:     Lady Gaga, Marine Le Pen, Romania: Your Monday Briefing - The New York Times
# Generated: confirmed controversial to hate controversial to hate with controversial to hate
#
# Input:      David Bowie is set to achieve in death what he could not in life — a No.
# Actual:     David Bowie proves death is great for album sales
# Generated: the UNK of the UNK
#
# Input:      Hillary Clinton has made Donald Trump’s remarks about a federal judge, among others, the basis for a
# campaign accusing him of being a racist.
# Actual:     Hillary Clinton, Racist: Top 5 Worst Comments (in Public)
# Generated: the new york not
#
# Input:      (CNN) President Donald Trump and Russian President Vladimir Putin are scheduled to speak on the
# phone Saturday in their first conversation since Trump took office, with Vice President Mike Pence
# joining the call.
# Actual:     Trump to speak with Putin on Saturday
# Generated: trump allegations to got with trump at omar male
#
# Input:      Evergreen State College Professor Bret Weinstein claimed that it may be unsafe for him to return to
# campus in his second interview with Tucker Carlson, which aired on Monday night.
# Actual:     Bret Weinstein to Tucker Carlson: It May Not be Safe to Return to Evergreen State - Breitbart
# Generated: the UNK of the UNK
#
# Input:      Ryan’s remarks extended an olive branch to Trump, the GOP with whom he is had an relationship since
# the start of the 2016 election cycle.
# Actual:     Ryan says Trump victory will unify Republicans, vows to work ’hand in hand’
# Generated: the UNK of the UNK
#
# Input:      If you are a cat lover living in or near Manchester, England, the purrfect job awaits.
# Actual:     Feline cafe will pay you $11 an hour to play with cats
# Generated: the UNK of oregon
#
# Input:      If you have Canadian friends, do not try to reach them tonight.
# Actual:     Canada’s unofficial poet laureate is dying. he is giving one last concert before he goes.
# Generated: the london is very to the london
#
# Input:      President Trump was talking about the global jihad.
# Actual:     The press, the president, and the jihad, &c.
# Generated: trump is starwood a UNK
#
# Input:      Deadpool and HBO’s Silicon Valley star T. J. Miller opened the 22nd annual Critics’ Choice Awards on
# Sunday by ribbing Donald Trump and the results of the 2016 presidential election.
# Actual:     T.J. Miller Mocks Donald Trump During 2016 Critics’ Choice Awards - Breitbart
# Generated: the UNK of the make games twitter of the headquarters
#
# Input:      Some details of the Orlando nightclub massacre are known to the minute: The first reports of gunfire
# came at 2:02 a. m. The gunman made a 911 call at 2:35 a. m. in which he pledged allegiance to the
# Islamic State.
# Actual:     Orlando Police Defend Actions as Clock Ticked in Massacre - The New York Times
# Generated: the UNK of the UNK
#
# Input:      From Olivia Nuzzi writing at The Daily Beast: The New York State Education Department is reviewing
# the Clinton Global Initiative University’s decision to use the term “university” in its name without
# explicit permission.
# Actual:     Clinton University Scam Another Disaster - Breitbart
# Generated: the UNK of the UNK one
#
# Input:      If you are a business, Donald Trump is making it hard to plan for the future.
# Actual:     The Folly of Trump’s Command Economy
# Generated: trump is times a UNK
#
# Input:      The chicken sector, which is dominated by a handful of large meat companies, has come under
# increased scrutiny over the past year as customers and farmers have alleged antitrust violations
# relating to pricing, production and compensation.
# Actual:     Tyson reveals subpoena linked to alleged price fixing
# Generated: the UNK of the facts serious blog of the make disaster blog
#
# Input:      Ms. Clinton’s plan is doomed to fail, because, like many before it, it funds pop psychology and
# ignores the most seriously mentally ill.
# Actual:     Why the Clinton Mental-Health Plan will not Succeed
# Generated: the new york not
#
# Input:      When a transgender woman tried to use the bathroom at a Giant grocery store in Washington, DC, she
# faced an unexpected obstacle: a security guard.
# Actual:     DC guard charged with assault after stopping transgender woman from using the bathroom
# Generated: the UNK of the make games building of the make games building
#
# Input:      After Betsy DeVos’ Senate confirmation hearing yesterday — all three hours and change — we know a
# little more about Donald Trump’s pick to be the next education secretary.
# Actual:     School Vouchers, Oligarchy And Grizzlies: Highlights From The DeVos Hearing
# Generated: the speechwriter prez
#
# Input:      When President Obama announced the details of the Partnership on Thursday — and released them on
# Medium.
# Actual:     How Obama’s Trade Deal Might Stir Up Your Dinner
# Generated: the UNK of the make games europe lives
#
# Input:      A good life lesson: once you do stupid, terrible things, pretty soon you have to end up saying
# stupid, terrible things.
# Actual:     Grassley Compares Garland to Foreign Dictator
# Generated: the russian italian of the UNK
#
# Input:      Per a PIX 11 report, Utah police are looking for answers after a father left his daughter in the
# middle of the night and left her in the cold.
# Actual:     Surveillance Video Shows Five-Year-Old Girl Left Outside Overnight in 39-Degree Weather - Breitbart
# Generated: trump says us will times be UNK after report departure
#
# Input:      Some recent developments in the godless West: The supreme court of Italy last week ruled that public
# masturbation is legal (except in front of minors).
# Actual:     How Is the Godless West Working Out?
# Generated: the leader of the facts make games ‘we of the row
#
# Input:      (CNN) Amnesty International has accused the Australian government of a ”mass ” after more than 2,
# 000 case reports were leaked detailing abuse on the Pacific island of Nauru.
# Actual:     Leaked files catalog cruelty and abuse on Nauru
# Generated: russia clinton UNK UNK
#
# Input:      A good friend of mine from the tech world is a serious proponent of the idea that the you. S. should
# restore the monarchy, along with the gold standard.
# Actual:     Ted Cruz Lost Because American Conservatives are Liberal
# Generated: the UNK of the make games watch
#
# Input:      Americans’ top concern about the tax code is that they want corporations and wealthy individuals to
# pay more taxes.
# Actual:     New poll shows what Americans really think about taxes: the rich should pay more
# Generated: the UNK of the women
#
# Input:      Every presidential campaign is full of unpredictable twists and turns.
# Actual:     Gaffe Track: that is No Sheriff’s Badge, Donald
# Generated: policy is times a UNK
#
# Input:      I want to receive updates from partners and sponsors.
# Actual:     Picking Sides in Captain America: Civil War
# Generated: the UNK of the UNK
#
# Input:      The documents released in the lawsuit against Trump University paint an unflattering picture.
# Actual:     Trump University Is Like Other For-Profit Colleges But Without The Degree
# Generated: the trump releases of the trump
#
# Input:      The invention of the microscope proved that these tiny, organisms live all around us.
# Actual:     The wouldark Matter’ of the Microbial World
# Generated: the UNK of the UNK
#
# Input:      Dear M. C.: Seasonal adjustments make perfect sense.
# Actual:     Dear John: Seasonal job adjustments matter
# Generated: the pro-brexit of the mob
#
# Input:      When Ricky Best and Taliesin boarded a train in Portland, Ore. on Friday night, they never could
# have imagined they would not make it home.
# Actual:     Attacks like Portland’s will keep happening unless we all fight white supremacy
# Generated: the UNK of the UNK
#
# Input:      Monday on MSNBC’s special primary coverage, Rep. Steve King ( ) a supporter of Republican
# presidential hopeful Sen. Ted Cruz ( ) responded to Donald Trump calling Cruz a “liar.
# Actual:     Steve King on Trump Calling Cruz Liar: ’Hamilton And Burr Fought to the Death Over Such Allegations’
# - Breitbart
# Generated: trump is times a UNK
#
# Input:      NEW YORK CITY, New York — Former Secretary of State Hillary Clinton, the Democratic nominee for
# president, had yet another coughing fit on her plane flight from Ohio to Iowa in front of the
# traveling press, ABC News reports.
# Actual:     Choke Artist: Hillary Clinton Has Yet Another Coughing Fit on Plane Ride from Ohio to Iowa -
# Breitbart
# Generated: the make disaster building of the make disaster people
#
# Input:      A Daily News editor who and triggered a plagiarism controversy has issued a public mea culpa and
# said severe cutbacks at the paper may have contributed to his bungling in the editing process.
# Actual:     Fired Daily News editor takes blame for Shaun King controversy
# Generated: policy UNK says us is times a UNK
#
# Input:      The law, passed by Iowa’s House and Senate last month, bans abortions once a pregnancy reaches 20
# weeks and stipulates a waiting period before women can undergo any abortion.
# Actual:     Iowa Supreme Court blocks portion of 20-week abortion ban
# Generated: the UNK of the UNK
#
# Input:      Third of Four Parts ... A Defining Event in Everyone’s Healthcare let us start with the central
# moment of healthcare as experienced by most Americans.
# Actual:     PINKERTON: Your Money or Your Life -- Fighting Over Obamacare vs. Fighting for Medical Cures
# Generated: the make disaster ‘we of voter
#
# Input:      President Barack Obama and Secretary of State John Kerry surprised many observers by devoting so
# much of their waning time in office to excoriating Israel.
# Actual:     Bailing Out the Palestinian Authority
# Generated: the new york president is times a UNK
#
# Input:      House Speaker Paul Ryan urged Republican investigators to focus on facts, responding to a New York
# Times report that President Donald Trump tried to stop an FBI investigation into his former National
# Security Advisor Mike Flynn.
# Actual:     Paul Ryan Calls for Facts After Comey Memo: People ‘Want to Hurt the President”
# Generated: trump is times a UNK for the UNK
#
# Input:      The Christian cross is “not an adornment for the house or a piece of jewelry to wear,” but a
# reminder of Christ’s love in saving mankind from evil and sin, Pope Francis said Sunday.
# Actual:     Pope Francis: The Cross Is ‘Not a Piece of Jewelry’ But Symbol of Christian Faith
# Generated: the when of the facts make disaster when traffic is a UNK
#
# Input:      ASTON, Pennsylvania — Ivanka Trump, the daughter of 2016 Republican presidential nominee Donald J.
# Trump, told Breitbart News exclusively here that her father’s campaign is offering actual solutions
# for Americans.
# Actual:     Exclusive — Ivanka Trump: ‘One of the Great Promises of a Trump Presidency Is Bringing New
# Solutions, Fresh Perspective’ - Breitbart
# Generated: the UNK of the UNK
#
# Input:      you would be forgiven for viewing nominations for the 59th Grammy Awards, announced Tuesday morning,
# as a battle between two powerhouse singers: Beyoncé, whose Lemonade leads the field with nine, and
# Adele, whose 25 has been a sales juggernaut since its release late last year.
# Actual:     Grammy Nominations Pit Beyoncé Against Adele
# Generated: the UNK of the UNK
#
# Input:      Last month, the Federal Bureau of Investigation obtained a court order requiring Apple to write new
# software and take other measures to disable passcode protection and allow access to shooter Rizwan
# Farook’s iPhone.
# Actual:     Apple ’raised technological barriers’ to stop warrant in iPhone case: you.S. government
# Generated: the could is times a UNK
#
# Input:      The Department of Plant Biology at has created a memorial page for postdoc Sharon Gray.
# Actual:     American researcher killed by protesters in Ethiopia
# Generated: the where of where
#
# Input:      Environmental Protection Agency head Scott Pruitt’s vow to shift the agency back towards the “vital”
# work of dealing with toxic sites that pollute air and water has been dashed by a White House budget
# plan that would slash funding for the .
# Actual:     White House proposes slashing funds to clean up toxic sites despite EPA’s pleas
# Generated: the UNK of the UNK
#
# Input:      ’ The popular Netflix show 13 Reasons Why is officially coming back for a second season.
# Actual:     "13 Reasons Why" Is Officially Coming Back For A Second Season
# Generated: the million for questions
#
# Input:      For us to continue writing great stories, we need to display ads.
# Actual:     The Protests After Police Shoot Another Black Man
# Generated: the UNK of the UNK
#
# Input:      Secretary of Labor Tom Perez quipped about an Amber alert on his phone during a Clinton campaign
# stop in North Carolina.
# Actual:     Hillary Surrogate Jokes About Amber Alert: ber Is Going To Vote For Hillary’ - Breitbart
# Generated: the leader clinton’s launches on cannot
#
# Input:      it is Day 3 of the Wimbledon tennis championships, and there is already a controversial new star: a
# Nike dress.
# Actual:     Wardrobe Malfunction: ’Power Pleat’ Causes Problems At Wimbledon
# Generated: the hell of the make games building of the make games nominees
#
# Input:      I want to receive updates from partners and sponsors.
# Actual:     Thelma & Louise Holds Up Well—A Little Too Well
# Generated: the UNK of the UNK
#
# Input:      This article is part of a feature we also send out via email as Politics Policy Daily, a daily
# roundup of events and ideas in American politics written specially for newsletter subscribers.
# Actual:     The Atlantic Politics & Policy Daily: Slow Nunes Day
# Generated: UNK UNK UNK UNK UNK UNK UNK
#
# Input:      Scholastic announced Sunday it was pulling ”A Birthday Cake for George Washington” from shelves
# after it received criticism for the way it depicted happy slaves.
# Actual:     Scholastic Pulls Children’s Book For The Way It Depicts Happy Slaves
# Generated: the UNK of the UNK
#
# Input:      TPM is hiring.
# Actual:     We Are Hiring
# Generated: the UNK of the UNK
#
# Input:      it is hangover time for the nation’s largest department stores.
# Actual:     Macy’s job cuts hammer retail stocks
# Generated: the UNK of the make games building of the serious officer grizzlies
#
# Input:      The latest York Times presidential poll shows Donald Trump and Hillary Clinton tied with 40 percent
# support — and tied in a race including Libertarian Gary Johnson at 36 percent support.
# Actual:     2016 Poll: Donald Trump Pulls Even with Hillary Clinton - Breitbart
# Generated: the million for the UNK of the UNK
#
# Input:      BALTIMORE — Ten years after the Kentucky Derby winner Barbaro sustained an eventually fatal injury
# in the Preakness Stakes, two horses died during the race’s undercard at Pimlico Race Course on
# Saturday, including a filly owned by Barbaro’s owners, Gretchen and Roy Jackson.
# Actual:     Two Horses Die During Preakness Undercard - The New York Times
# Generated: the UNK of the UNK
#
# Input:      Iceland Airwaves may not have the AR reputation of South by South West or CMJ, but it does offer as
# wide a variety of new music as any festival, both local and international (with an obvious focus on
# Icelandic and Scandinavian talent).
# Actual:     Iceland Airwaves festival day four – Björk’s the star in her home country
# Generated: the UNK of the UNK
#
# Input:      Attention, Harry Potter fans.
# Actual:     Harry Potter Fans, Rejoice! New Book From The Wizarding World Coming This Summer
# Generated: dance UNK UNK UNK UNK our at rot
#
# Input:      A daughter of an Illinois state representative has been charged with participating in an attack on
# one of her mother’s political rivals that included using a staple gun on the victim’s forehead,
# police and the victim said on Friday.
# Actual:     Lawmaker’s daughter accused of attacking mom’s rival with a staple gun
# Generated: one executive nominee to lawmakers denying to denying
#
# Input:      The leaders of the Senate intelligence committee have pledged that their investigation of Russian
# interference in last year’s presidential election will be independent and bipartisan, as a bitter
# dispute continues to cloud a similar inquiry in the House of Representatives.
# Actual:     Senators vow Trump-Russia inquiry will be bipartisan and independent
# Generated: takes UNK UNK UNK UNK UNK UNK
#
# Input:      Speaking at a rally in Tampa, Fla. on Wednesday, Hillary Clinton told the story of a leukemia
# patient named Steven who ”ditched his oxygen tank,” as Clinton told it, to vote early.
# ...
# device.
# Actual:     you.S. Agency Calls Hoverboards An “Imminent Hazard,” Puts Forth New Safety Standards
# Generated: the new york not
#
# Input:      Janet L. Yellen, the Federal Reserve chairwoman, made it clear Wednesday that she believes that the
# American economy is pretty much back on track.
# Actual:     Donald Trump and Janet Yellen Look to Be on a Collision Course - The New York Times
# Generated: the UNK of bank bank bank watch
#
# Input:      On his Thursday Fox Sports 1 radio show, Colin Cowherd slammed quarterback Colin Kaepernick’s
# courage for choosing to end his national anthem protest now that he is looking for a job in the NFL,
# calling the quarterback a “sellout.
# Actual:     FS1’s Cowherd Slams ’Sellout’ Kaepernick: where is Your Courage Now That you are a Free Agent? -
# Breitbart
# Generated: the new york not
#
# Input:      Despite holding out hope for an agreement on a deal, the Washington Redskins and Kirk Cousins have
# failed to do so, and in turn, the team will use the franchise tag by today’s 4 p. m. deadline to
# ensure that it does not lose the quarterback on the free agent
# Actual:     Redskins will use franchise tag to retain the rights to Kirk Cousins
# Generated: sex merkel to be UNK for UNK
#
# Input:      A top Secret Service official quit Monday only a week after a new boss was put in charge of the
# troubled agency.
# Actual:     Top Secret Service agent quits a week after new boss begins
# Generated: the UNK of the UNK
#
# Input:      President Obama on Friday vetoed legislation that would allow families of victims to sue Saudi
# Arabia over its alleged ties to the terrorists who carried out the attacks.
# Actual:     Obama vetoes 9/11 bill, likely setting up first congressional override of his presidency
# Generated: the leader street stop clinton’s have
#
# Input:      An Italian couple have been killed after a motorway bridge collapsed on top of their car, in Italy’s
# second such tragedy in just over four months.
# Actual:     Motorway bridge collapse in Italy kills couple
# Generated: the new york not
#
# Input:      After all the allegations of rampant voter fraud and claims that millions had voted illegally, the
# people who supervised the general election last month in states around the nation have been adding
# up how many credible reports of fraud they actually received.
# Actual:     All This Talk of Voter Fraud? Across you.S., Officials Found Next to None - The New York Times
# Generated: the bruising of the make games building of the make games building of the make games building
#
# Input:      If Marco Rubio or Ted Cruz makes it to the White House, it will be historic — it would mean this
# country had its first ever Latino president.
# Actual:     Why Cruz And Rubio cannot Count On The Latino Vote
# Generated: the leader of the UNK
#
# Input:      Hillary Clinton may not like to use the word “terrorist,” but the New York Times has no problem
# using that word — to refer to Donald Trump, at least.
# Actual:     New York Times: Donald Trump Is a ’Terrorist’ - Breitbart
# Generated: the new york not
#
# Input:      Several relatives of victims of the Sept. 11 attacks on New York and Washington criticized President
# Donald Trump’s executive order on immigration on Tuesday, saying they did not want the memories of
# those killed used to justify harming refugees.
# Actual:     Some Sept. 11 families join criticism of Trump immigration order
# Generated: the new york during of the because
#
# Input:      That s the thinking behind the bug bounty program at Slack, the popular platform, which offers a to
# people who find and report legitimate security flaws that could be exploited by hackers.
# Actual:     The Bounty Hunters Protecting Your Slack Account
# Generated: the UNK fractured who bowl force’ share
#
# Input:      President Obama’s threat was direct and unequivocal: The United States will retaliate against Russia
# for its cyberattacks.
# Actual:     Will Obama Order American Hackers to Dox Putin?
# Generated: the hell street stop clinton’s trump is times a UNK
#
# Input:      EDINBURGH, Scotland — Even by the blustery standards of this notoriously land, Aug. 7 was a
# particularly gusty day.
# Actual:     In Scotland, gusts of wind usher in a quiet energy revolution
# Generated: the UNK of the UNK
#
# Input:      During Friday’s Weekly Address, President Trump stated, “Confidence in the American economy has
# reached levels not seen in many, many years.
# Actual:     Trump: Confidence In Economy ’Has Reached Levels Not Seen In Many, Many Years’ - Breitbart
# Generated: the UNK of the UNK
#
# Input:      Hackers have targeted Ukrainian state institutions about 6, 500 times in the past two months,
# including incidents that showed Russian security services were waging a cyberwar against the
# country, President Petro Poroshenko said on Thursday.
# Actual:     Ukraine hit by 6,500 hack attacks, sees Russian ’cyberwar’
# Generated: the new york not
#
# Input:      Simone Biles is America’s darling and one of the biggest stars in attendance at the 2016 Rio
# Olympics.
# Actual:     Simone Biles is still melting after surprise Zac Efron kiss
# Generated: the UNK of the make disaster ‘we of the make disaster ‘we
#
# Input:      The Sanders campaign is ending with a whimper.
# Actual:     Will Conservatives Court Millennials?
# Generated: the UNK of the UNK
#
# Input:      It was a tokin’ gesture.
# Actual:     Marijuanalujah? Jeff Sessions and the cannabis conundrum
# Generated: the UNK of the UNK
#
# Input:      (CNN) Pope Francis delivered yet another biting critique of contemporary capitalism on Saturday,
# saying the poor are often sacrificed on the ”altar of money” and accusing the wealthy of worshipping
# a new ”golden calf.” ”Certainly every culture needs economic growth and the creation of wealth,” the
# Pope told a group
# Actual:     Pope: Poor are sacrificed on ’the altar of money’
# Generated: troops on earthquake of give UNK UNK
#
# Input:      Voice recognition surrounds Americans, from Siri to Google Assistant to Amazon Echo.
# Actual:     Turn On, Tune In, Transcribe: you.N. Develops Radio-Listening Tool
# Generated: the UNK of the UNK
#
# Input:      The French president, François Hollande, has said his country has “a problem with Islam” and that
# there are too many illegal migrants arriving in France.
# Actual:     François Hollande: France has ’a problem with Islam’
# Generated: the UNK of the UNK
#
# Input:      BERLIN (AP) — German Chancellor Angela Merkel is likely to meet with you. S. Vice President Mike
# Pence next week.
# Actual:     Germany’s Merkel to Meet Trump’s Vice President Pence Next Week
# Generated: these department mass are times go to be a UNK
#
# Input:      ’What We Know So Far’ areaction From the Tennis World’ ’John Whittingdale, you. K. secretary of
# state for culture, media, and sport, said he is talking to tennis officials, stressing that they
# need to make sure the “game is absolutely clean.
# Actual:     Tennis World Reacts To Match-Fixing Expose
# Generated: hillary clinton UNK UNK UNK UNK UNK
#
# Input:      Dwyane Wade has lashed out against his hometown of Chicago’s gun laws, calling them weak and saying
# he has already urged city officials to enact changes to help both citizens and police.
# Actual:     NBA star Dwyane Wade calls Chicago’s gun laws weak after cousin’s death
# Generated: the UNK of the UNK of the UNK
#
# Input:      How Oklahoma City has rebuilt many of its school athletic facilities, boosting athletic
# participation and graduation rates.
# Actual:     Fields of dreams for local schools
# Generated: during meryl to every word istanbul for soldiers
#
# Input:      ”The 2016 NBA Finals has reached for the Cleveland Cavaliers and the Golden State Warriors, and
# ticket prices for Sunday’s Game 7 appear to be doing the same.”
# Actual:     Tickets for the NBA Finals Game 7 are going for unreal prices
# Generated: the UNK one of the UNK one
#
# Input:      let us be clear: Donald Trump is not proposing to raise the price of your avocados in order to pay
# for a border wall.
# Actual:     Donald Trump’s "paying for the wall by hiking prices on avocados" controversy, explained
# Generated: trump is times go to be a UNK
#
# Input:      A day with the you. S. Air Force starts early.
# Actual:     Commentary: An unusual view of the you.S. Air Force’s F-22
# Generated: the because is me a service off with the UNK
#
# Input:      People will look back on this era in our history to see what was known about Donald Trump while
# Americans were deciding whether to choose him as president.
# Actual:     Trump Time Capsule #45: Why Melania’s Speech Matters
# Generated: the trump releases of the trump releases
#
# Input:      GOP frontrunner Donald Trump has launched a new radio ad in Wisconsin ahead of the Badger State
# primary on April 5th, next Tuesday, even as many of the conservative radio voices in Wisconsin are
# criticizing him.
# Actual:     Donald Trump Rallies Badger State as Ted Cruz Leads Polls: ‘we are Coming for You, Wisconsin’ -
# Breitbart
# Generated: the trump seller
#
# Input:      Talk radio host Sean Hannity argued that perceptions of the incident between Trump campaign manager
# Corey Lewandowski and reporter Michelle Fields “are based on who they support for the nomination”
# and that the incident was “nothing” on Wednesday.
# Actual:     Hannity: Perceptions of Lewandowski-Fields Incident Based on Who People Support - Incident Is
# ’Nothing’ - Breitbart
# Generated: president clinton UNK to office him from him let president
#
# Input:      ‘Pride goeth before destruction,” Proverbs 16:18 reminds us, and so it was in this election.
# Actual:     Obama’s ‘legacy’ drive lost Florida for Clinton
# Generated: the UNK of the facts make hunt hunt hunt hunt hunt hunt hunt hunt bosses
#
# Input:      ISTANBUL — A Kurdish politician who had been missing from southeastern Turkey since May resurfaced
# in Iraq on Friday after months of speculation that the Turkish authorities had detained him.
# Actual:     Kurdish Politician Who Vanished in Turkey Turns Up in Iraq - The New York Times
# Generated: the leader of the UNK of the UNK
#
# Input:      A boy in a stroller was injured in Brooklyn on Tuesday, when a man fighting with another threw a
# glass bottle, hitting the child above the eye.
# Actual:     Brawl in broad daylight ends with little boy gruesomely injured
# Generated: the UNK of years prison ’a
#
# Input:      (CNN) In what appeared to be an improvised moment, President Donald Trump invited one of his
# supporters to join him on stage and take the microphone during a rally in Melbourne, Florida, on
# Saturday night.
# Actual:     Trump hands mic to supporter at Florida rally
# Generated: trump cox his suspect mission with russia
#
# Input:      The WWE is aiming for a knockout against wrestler Paige in an ongoing public feud.
# Actual:     WWE fires back at banned beauty: Spreading lies about drug test
# Generated: the UNK of the give
#
# Input:      you. S. Donald Trump on Wednesday said telecommunications group Sprint Corp ( ) and a you. S.
# satellite company OneWeb will bring 8, 000 jobs to the United States, and the companies said the
# positions were part of a previously disclosed pledge by Japan’s SoftBank Group Corp. SoftBank ( )
# Actual:     Sprint, OneWeb say 8,000 jobs announced by Trump are part of SoftBank pledge
# Generated: trump is times a UNK
#
# Input:      China ”appears to have built significant capabilities” on artificial islands in the South China Sea,
# says a think tank that cites new satellite imagery showing hexagonal gun platforms and other recent
# construction.
# Actual:     In South China Sea Islands, Anti-Aircraft And Radar Systems Emerge In Full Color
# Generated: the UNK of the UNK UNK
#
# Input:      — Walter White, “Breaking Bad” Substitute “relievers” for “gold” (and “are” for “is,” and “them” for
# “it,” if you are a stickler) and you have yourself what is left of this baseball offseason.
# Actual:     What would spur Yanks and Mets to end game of bullpen chicken
# Generated: the UNK of the UNK
#
# Input:      “Riverdale” star Cole Sprouse has gotten a lot edgier since playing Ross’ (David Schwimmer) adorable
# son Ben in later episodes of the sitcom “Friends.
# Actual:     ‘Riverdale’ actor crushed on Jennifer Aniston as kid star on ‘Friends’
# Generated: the UNK of the celebrity
#
# Input:      Washington (CNN) Mike Pence was chosen as Donald Trump’s vice presidential nominee in part because
# of his ability to stay on message and maintain his relationships with fellow Republicans even under
# political pressure.
# Actual:     Pence’s role: Trump’s apologizer-in-chief
# Generated: the UNK of the UNK
#
# Input:      , Brazilian prosecutors have charged Luiz Inácio Lula da Silva with being the “maximum commander”
# of a vast corruption scheme at the state oil company, Petrobras, in a major blow to the leftist
# hero’s hopes of a political comeback.
# Actual:     Brazil’s ex-president Lula charged with corruption in oil kickback scandal
# Generated: the UNK of the UNK of the UNK
#
# Input:      it is perhaps the unlikeliest symphony orchestra in the world — an ensemble from a strict Muslim
# society where it is often dangerous for young women to step outside of their homes unescorted.
# Actual:     All-Female Orchestra From Afghanistan Is A Force For Change
# Generated: UNK UNK to every join states in states
#
# Input:      Rudy Giuliani went to bat for Donald Trump during the Republican nominee’s campaign rally in
# Fayetteville, North Carolina on Tuesday night after Hillary Clinton’s campaign alleged Trump
# suggested gun owners assassinate her if she is elected president.
# Actual:     Rudy Giuliani to Clinton Campaign: ’Are You Out of Your Mind?’
# Generated: UNK trump is a UNK tell
#
# Input:      It has become a familiar pattern in Connecticut over the last few years.
# Actual:     Rust Belt Connecticut
# Generated: the leader of the UNK
#
# Input:      At Lambeau Field on Sunday afternoon, as Senator Ron Johnson mingled with the crowd — enjoying a
# brat and beer, chatting with fellow Packers fans, and taking selfies — he looked like a man at ease.
# Actual:     Ron Johnson Is Sprinting to the Finish in Wisconsin
# Generated: sam’s UNK UNK UNK UNK UNK UNK
#
# Input:      With the New Year comes a long list of new laws taking effect across the country.
# Actual:     New Year, New Laws: States Diverge On Gun Rights, Voting Restrictions
# Generated: the UNK of the keep
#
# Input:      ’’ ’February has been a tough month for the enterprise tech market.’ ’Companies like LinkedIn and
# Tableau saw their stock prices hit their worst declines in history after giving weak earnings and
# guidance numbers.
# Actual:     Salesforce just debunked an idea that was driving the entire tech market down
# Generated: UNK UNK UNK UNK UNK UNK UNK UNK
#
# Input:      PORTLAND, Ore. — As military helicopters ferry search and rescue teams over the Pacific Northwest,
# below them are scenes of devastation from a giant earthquake that could strike the region at any
# time.
# Actual:     Pacific Northwest preps for the Big One
# Generated: the UNK of the two
#
# Input:      California police were asking for the public’s help Friday in finding a missing Air Force veteran
# and father of three who disappeared under suspicious circumstances nearly one week ago.
# Actual:     California police search for missing Air Force veteran and father of 3
# Generated: UNK UNK UNK UNK UNK with UNK
#
# Input:      Over the last few weeks, it seemed like Neiman Marcus could not make up its mind about whether to
# sell Ivanka Trump’s fine jewelry.
# Actual:     Ivanka Trump to End Fine Jewelry Line in Favor of Mass-Market One - The New York Times
# Generated: the leader of the two
#
# Input:      you. S. Republican presidential candidate Donald Trump offered a message of ethnic harmony on Friday
# at a Christian evangelical conference as he sought to calm concern about his criticism of a judge.
# Actual:     Stung by criticism, Trump vows to work for ethnic harmony
# Generated: it pulled better ever is 25-year to be it
#
# Input:      Millions of people around the world went to the polls this year.
# Actual:     10 Elections to Watch in 2017
# Generated: the make disaster putin, of country

# %%
model.get_diversity_metrics(checkpoint, x_test, y_test)
# Out:
# INFO:tensorflow:Restoring parameters from /Users/m3hrdadfi/Projects/hooshvare/ved/outputs/ved-var-attn/checkpoints/var-seq2seq-with-atten-7.ckpt
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-262000571846> in <module>()
# ----> 1 model.get_diversity_metrics(checkpoint, x_test, y_test)
#
# ~/Projects/hooshvare/ved/ved_var_attn.py in get_diversity_metrics(self, checkpoint, x_test, y_test, num_samples, num_iterations)
#     531                         self.word_dropout_keep_prob: 1.0,
#     532                         self.z_temperature: self.z_temp,
# --> 533                         self.attention_temperature: self.attention_temp})
#     534                     answer_logits.extend(result)
#     535
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
